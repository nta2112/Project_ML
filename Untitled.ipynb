# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\OneDrive\OneDrive - Thuyloi University\Document_OneDrive\Dev Document\AI\Deep_Learning\TimeSieri\weatherAUS.csv\weatherAUS.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


def vebd(link):
  df = pd.read_parquet(link)
  # print(df)
  plt.figure(figsize=(20, 6))
  plt.plot(df.close, marker="o")
  plt.xticks(rotation=45)
  plt.xlabel("Time", fontsize=12)
  # plt.ylabel("Shampoo revenue", fontsize=12)
  plt.title(f"{link}", fontsize=18)
  plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])


plt.figure(figsize=(20, 6))
plt.plot(df.MinTemp, marker="o")
plt.xticks(rotation=45)
plt.xlabel("Date", fontsize=12)
plt.title(f"MinTemp", fontsize=18)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Giả sử bạn đã có DataFrame df
df = pd.read_csv(r"D:\OneDrive\OneDrive - Thuyloi University\Document_OneDrive\Dev Document\AI\Deep_Learning\TimeSieri\weatherAUS.csv\weatherAUS.csv")
df['Date'] = pd.to_datetime(df['Date'])

plt.figure(figsize=(20, 6))
plt.plot(df['Date'], df['MinTemp'])  # ✅ sửa ở đây
plt.xticks(rotation=45)
plt.xlabel("Date", fontsize=12)
plt.ylabel("MinTemp", fontsize=12)
plt.title("MinTemp theo thời gian", fontsize=18)
plt.tight_layout()
plt.show()

# %%
# Mann-Kendall Test
from pymannkendall import original_test
result = original_test(rainfall_data)
print(f"Tau: {result.Tau}, p-value: {result.p}")

# Sen's Slope Estimator
from pymannkendall import sens_estimator
slope, intercept = sens_estimator(rainfall_data)
print(f"Xu hướng Sen's slope: {slope} mm/năm")
